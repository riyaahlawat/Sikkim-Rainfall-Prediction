# %%
import pandas as pd

# Load the dataset
df = pd.read_excel(r"C:\Users\rahla\Desktop\Sikkim-Rainfall-Prediction\Combined Datasets\Location_0_1978_to_2022.xlsx")  # Replace with your actual file path

# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')  # Adjust format if necessary

# Drop rows with missing values in 'Rainfall' or 'Date'
df.dropna(subset=['Rainfall (in mm)'], inplace=True)

# Select only the 'Date' and 'Rainfall' columns
df = df[['Date', 'Rainfall (in mm)']]

# Set the 'Date' column as the index
df.set_index('Date', inplace=True)

# Convert Rainfall to time series (assuming daily data)
rainfall_ts = df['Rainfall (in mm)']

# Display the first few rows to check the data
print(df.head())
# Out:
#             Rainfall (in mm)
# Date
# 1978-01-01               1.0
# 1978-01-02               0.0
# 1978-01-03               0.0
# 1978-01-04               0.0
# 1978-01-05               0.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from scipy.signal import periodogram

# Check for stationarity using Augmented Dickey-Fuller test
def check_stationarity(ts):
    result = adfuller(ts)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    if result[1] <= 0.05:
        print("The series is stationary")
    else:
        print("The series is not stationary")

# Apply stationarity check
check_stationarity(rainfall_ts)

# Fourier Transform (Periodogram)
frequencies, power = periodogram(rainfall_ts)

# Plot the periodogram
plt.figure(figsize=(10, 6))
plt.semilogy(frequencies, power)
plt.title("Periodogram (Fourier Transform) of Rainfall Data")
plt.xlabel('Frequency')
plt.ylabel('Power')
plt.grid(True)
plt.show()
# Out:
# ADF Statistic: -9.437585
# p-value: 0.000000
# The series is stationary

# %%
import numpy as np
import pandas as pd
from scipy.signal import periodogram

# Assuming rainfall_ts is your time series data

# Apply periodogram
frequencies, power = periodogram(rainfall_ts)

# Convert frequency to period
periods = 1 / frequencies

# Create a DataFrame
periodogram_df = pd.DataFrame({'period': periods, 'spec': power})

# Sort by power (spec) in descending order and get top 2 frequencies
top_frequencies = periodogram_df.sort_values(by='spec', ascending=False).head(2)

print(top_frequencies)
# Out:
#         period           spec
# 44  367.954545  307999.194073
# 45  359.777778   98067.780233
# C:\Users\rahla\AppData\Local\Temp\ipykernel_16712\2256149741.py:11: RuntimeWarning: divide by zero encountered in divide
#   periods = 1 / frequencies

# %%
# The periods 364.94 days and 365.69 days are very close to 365 days, which suggests that your dataset exhibits a strong 
# annual seasonal pattern.

# %%
# !pip install pmdarima

# %%
# import numpy as np
# import pandas as pd
# from pmdarima import auto_arima
# from sklearn.model_selection import train_test_split

# # Assuming rainfall_df is your DataFrame with Date and Rainfall columns
# rainfall_ts = df['Rainfall (in mm)'].values  # Your time series data (in mm)

# # Check the size of the dataset
# data_size = len(rainfall_ts)
# print(f"Dataset size: {data_size}")

# # Decide the train size (e.g., 80% of the data for training)
# train_size = int(data_size * 0.8)  # 80% for training, adjust as needed

# # Split the data into train and test sets
# y_train = rainfall_ts[:train_size]
# y_test = rainfall_ts[train_size:]

# # Fit the base ARIMA model
# model = auto_arima(y_train, seasonal=True, m=365, stepwise=True, trace=True)

# # Get AICc and other model parameters
# best_fit = {'aicc': model.aic(), 'i': model.order[0], 'j': model.order[1], 'fit': model}
# print(best_fit)
# Out:
# Dataset size: 178090
# Performing stepwise search to minimize aic
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~\AppData\Local\Temp\ipykernel_17648\3170802005.py in <module>
#      20 # Fit the base ARIMA model
# ---> 21 model = auto_arima(y_train, seasonal=True, m=365, stepwise=True, trace=True)
#      22
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\auto.py in auto_arima(y, X, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     700
# --> 701     sorted_res = search.solve()
#     702     return _return_wrapper(sorted_res, return_valid_fits, start, trace)
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py in solve(self)
#     287         # fit a baseline p, d, q model
# --> 288         self._do_fit((p, d, q), (P, D, Q, m))
#     289
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py in _do_fit(self, order, seasonal_order, constant)
#     234
# --> 235             fit, fit_time, new_ic = self._fit_arima(
#     236                 order=order,
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\_auto_solvers.py in _fit_candidate_model(y, X, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, information_criterion, **kwargs)
#     507     try:
# --> 508         fit.fit(y, X=X, **fit_params)
#     509
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\arima.py in fit(self, y, X, **fit_args)
#     602         # Internal call
# --> 603         self._fit(y, X, **fit_args)
#     604
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\arima.py in _fit(self, y, X, **fit_args)
#     523                 warnings.simplefilter('ignore')
# --> 524                 fit, self.arima_res_ = _fit_wrapper()
#     525         else:
#
# ~\anaconda3\lib\site-packages\pmdarima\arima\arima.py in _fit_wrapper()
#     509             disp = fit_args.pop("disp", 0)
# --> 510             fitted = arima.fit(
#     511                 start_params=start_params,
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     703             fargs = (flags,)
# --> 704             mlefit = super(MLEModel, self).fit(start_params, method=method,
#     705                                                fargs=fargs,
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     562         optimizer = Optimizer()
# --> 563         xopt, retvals, optim_settings = optimizer._fit(f, score, start_params,
#     564                                                        fargs, kwargs,
#
# ~\anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     240         func = fit_funcs[method]
# --> 241         xopt, retvals = func(objective, gradient, start_params, fargs, kwargs,
#     242                              disp=disp, maxiter=maxiter, callback=callback,
#
# ~\anaconda3\lib\site-packages\statsmodels\base\optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     650
# --> 651     retvals = optimize.fmin_l_bfgs_b(func, start_params, maxiter=maxiter,
#     652                                      callback=callback, args=fargs,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_lbfgsb_py.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     198
# --> 199     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
#     200                            **opts)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_lbfgsb_py.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     307
# --> 308     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     309                                   bounds=new_bounds,
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     262     # calculation reduces overall function evaluations.
# --> 263     sf = ScalarFunction(fun, x0, args, grad, hess,
#     264                         finite_diff_rel_step, bounds, epsilon=epsilon)
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     157         self._update_fun_impl = update_fun
# --> 158         self._update_fun()
#     159
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in _update_fun(self)
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in update_fun()
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#
# ~\anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py in fun_wrapped(x)
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#
# ~\anaconda3\lib\site-packages\statsmodels\base\model.py in f(params, *args)
#     530         def f(params, *args):
# --> 531             return -self.loglike(params, *args) / nobs
#     532
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in loglike(self, params, *args, **kwargs)
#     938
# --> 939         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     940
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in loglike(self, **kwargs)
#     986         if not (kwargs['conserve_memory'] & MEMORY_NO_LIKELIHOOD):
# --> 987             loglike = np.sum(kfilter.loglikelihood[loglikelihood_burn:])
#     988         else:
#
# ~\anaconda3\lib\site-packages\numpy\core\overrides.py in sum(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2297
# -> 2298     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2299                           initial=initial, where=where)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in <dictcomp>(.0)
#      69 def _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs):
# ---> 70     passkwargs = {k: v for k, v in kwargs.items()
#      71                   if v is not np._NoValue}
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# KeyboardInterrupt:

# %%
from pmdarima import auto_arima

# Set train and test sizes
train_size = 600
test_size = 100

# Split the data into train and test sets
y_train = rainfall_ts[:train_size]
y_test = rainfall_ts[train_size:train_size + test_size]

# Fit a faster ARIMA model
model = auto_arima(y_train, seasonal=True, m=7, stepwise=True,  
                   max_p=3, max_q=3, max_d=2,  
                   max_P=2, max_Q=2, max_D=1,  
                   trace=True, suppress_warnings=True)

# Get AICc and other model parameters
best_fit = {'aicc': model.aic(), 'i': model.order[0], 'j': model.order[1], 'fit': model}
print(best_fit)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=4129.589, Time=2.09 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=4294.268, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=4267.872, Time=0.25 sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=4205.687, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=4292.276, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=4131.218, Time=0.72 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=4130.962, Time=0.71 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=4131.221, Time=3.20 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=4131.136, Time=3.48 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=4136.215, Time=0.35 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=4133.110, Time=2.30 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=4132.746, Time=2.00 sec
#  ARIMA(2,1,2)(2,0,2)[7] intercept   : AIC=4131.675, Time=5.02 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=4127.762, Time=1.04 sec
#  ARIMA(1,1,2)(0,0,1)[7] intercept   : AIC=4129.475, Time=0.49 sec
#  ARIMA(1,1,2)(1,0,0)[7] intercept   : AIC=4129.236, Time=0.45 sec
#  ARIMA(1,1,2)(2,0,1)[7] intercept   : AIC=4129.478, Time=1.54 sec
#  ARIMA(1,1,2)(1,0,2)[7] intercept   : AIC=4129.414, Time=2.71 sec
#  ARIMA(1,1,2)(0,0,0)[7] intercept   : AIC=4134.232, Time=0.21 sec
#  ARIMA(1,1,2)(0,0,2)[7] intercept   : AIC=4131.360, Time=1.40 sec
#  ARIMA(1,1,2)(2,0,0)[7] intercept   : AIC=4131.007, Time=0.77 sec
#  ARIMA(1,1,2)(2,0,2)[7] intercept   : AIC=4130.026, Time=4.08 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=4125.815, Time=0.77 sec
#  ARIMA(0,1,2)(0,0,1)[7] intercept   : AIC=4127.478, Time=0.40 sec
#  ARIMA(0,1,2)(1,0,0)[7] intercept   : AIC=4127.243, Time=0.26 sec
#  ARIMA(0,1,2)(2,0,1)[7] intercept   : AIC=4127.502, Time=1.37 sec
#  ARIMA(0,1,2)(1,0,2)[7] intercept   : AIC=4127.434, Time=2.36 sec
#  ARIMA(0,1,2)(0,0,0)[7] intercept   : AIC=4132.364, Time=0.17 sec
#  ARIMA(0,1,2)(0,0,2)[7] intercept   : AIC=4129.370, Time=0.74 sec
#  ARIMA(0,1,2)(2,0,0)[7] intercept   : AIC=4129.030, Time=0.59 sec
#  ARIMA(0,1,2)(2,0,2)[7] intercept   : AIC=4128.036, Time=3.11 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=4202.820, Time=0.54 sec
#  ARIMA(0,1,3)(1,0,1)[7] intercept   : AIC=4127.756, Time=0.87 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=4143.472, Time=0.91 sec
#  ARIMA(1,1,3)(1,0,1)[7] intercept   : AIC=4129.112, Time=1.40 sec
#  ARIMA(0,1,2)(1,0,1)[7]             : AIC=4123.996, Time=0.37 sec
#  ARIMA(0,1,2)(0,0,1)[7]             : AIC=4125.674, Time=0.16 sec
#  ARIMA(0,1,2)(1,0,0)[7]             : AIC=4125.435, Time=0.16 sec
#  ARIMA(0,1,2)(2,0,1)[7]             : AIC=4125.687, Time=0.79 sec
#  ARIMA(0,1,2)(1,0,2)[7]             : AIC=4125.619, Time=1.05 sec
#  ARIMA(0,1,2)(0,0,0)[7]             : AIC=4130.559, Time=0.11 sec
#  ARIMA(0,1,2)(0,0,2)[7]             : AIC=4127.562, Time=0.49 sec
#  ARIMA(0,1,2)(2,0,0)[7]             : AIC=4127.217, Time=0.35 sec
#  ARIMA(0,1,2)(2,0,2)[7]             : AIC=4126.233, Time=1.50 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=4200.893, Time=0.36 sec
#  ARIMA(1,1,2)(1,0,1)[7]             : AIC=4125.948, Time=0.51 sec
#  ARIMA(0,1,3)(1,0,1)[7]             : AIC=4125.942, Time=0.49 sec
#  ARIMA(1,1,1)(1,0,1)[7]             : AIC=4141.703, Time=0.36 sec
#  ARIMA(1,1,3)(1,0,1)[7]             : AIC=4127.302, Time=0.74 sec
#
# Best model:  ARIMA(0,1,2)(1,0,1)[7]
# Total fit time: 54.178 seconds
# {'aicc': 4123.996004222067, 'i': 0, 'j': 1, 'fit': ARIMA(order=(0, 1, 2), scoring_args={}, seasonal_order=(1, 0, 1, 7),
#       suppress_warnings=True, with_intercept=False)}

# %%
import matplotlib.pyplot as plt  
from statsmodels.tsa.arima.model import ARIMA  

# Forecast for next 60 time steps  
forecast_steps = 60  
fc0 = model.predict(n_periods=forecast_steps)  

# Plot the forecast  
plt.figure(figsize=(10, 5))  
plt.plot(range(len(y_train)), y_train, label="Training Data")  
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label="Test Data", color='orange')  
plt.plot(range(len(y_train), len(y_train) + forecast_steps), fc0, label="Forecast", color='red', linestyle='dashed')  
plt.xlabel("Time")  
plt.ylabel("Rainfall (mm)")  
plt.legend()  
plt.title("Rainfall Forecast")  
plt.show()
# Out:
# C:\Users\rahla\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\rahla\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import numpy as np
import pandas as pd
from pmdarima import auto_arima
from statsmodels.tsa.stattools import acf
from statsmodels.tsa.tsatools import detrend

# Define Fourier terms function
def fourier_terms(time_series, period, K):
    """Generate Fourier terms for a given seasonal period and number of harmonics K."""
    t = np.arange(len(time_series))
    terms = np.column_stack([np.sin(2 * np.pi * k * t / period) for k in range(1, K + 1)] +
                            [np.cos(2 * np.pi * k * t / period) for k in range(1, K + 1)])
    return terms

# Initialize best fit storage
best_fit = {'aicc': np.inf, 'i': 0, 'j': 0, 'model': None}

# Define seasonal periods
seasonality_1 = 367.95
seasonality_2 = 359.77

# Loop over different Fourier terms to find the best AICc
for i in range(1, 4):  # Vary K1 from 1 to 3
    for j in range(1, 4):  # Vary K2 from 1 to 3
        # Generate Fourier terms
        z1 = fourier_terms(y_train, seasonality_1, i)
        z2 = fourier_terms(y_train, seasonality_2, j)
        xreg = np.hstack([z1, z2])  # Combine Fourier terms

        # Fit ARIMA model with external regressors
        model = auto_arima(y_train, exogenous=xreg, seasonal=False, stepwise=True, suppress_warnings=True)

        # Check if current model has a lower AICc
        if model.aic() < best_fit['aicc']:
            best_fit = {'aicc': model.aic(), 'i': i, 'j': j, 'model': model}

# Print best model details
print("Best AICc:", best_fit['aicc'])
print("Best Fourier Terms:", "K1 =", best_fit['i'], ", K2 =", best_fit['j'])
# Out:
# Best AICc: 4130.558893230089
# Best Fourier Terms: K1 = 1 , K2 = 1

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Generate Fourier terms for forecasting horizon (h=60)
horizon = 60
z1_future = fourier_terms(np.arange(horizon), seasonality_1, best_fit['i'])
z2_future = fourier_terms(np.arange(horizon), seasonality_2, best_fit['j'])
xreg_future = np.hstack([z1_future, z2_future])  # Combine Fourier terms

# Forecast using the best ARIMA model (correct reference to the model)
forecast_values, conf_int = best_fit['model'].predict(n_periods=horizon, exogenous=xreg_future, return_conf_int=True)

# Plot the forecast with actual test data
plt.figure(figsize=(10, 5))
plt.plot(range(len(y_train)), y_train, label="Train Data", color='blue')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label="Actual Test Data", color='green')
plt.plot(range(len(y_train), len(y_train) + horizon), forecast_values, label="Forecast", color='red')
plt.fill_between(range(len(y_train), len(y_train) + horizon),
                 conf_int[:, 0], conf_int[:, 1], color='red', alpha=0.2)

# Labels and legend
plt.legend()
plt.title("ARIMA Forecast with Fourier Terms vs. Actual Test Data")
plt.xlabel("Time")
plt.ylabel("Rainfall")
plt.show()
# Out:
# C:\Users\rahla\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\rahla\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# !pip install tbats
# Out:
# Collecting tbats
#   Downloading tbats-1.1.3-py3-none-any.whl (44 kB)
#      ---------------------------------------- 44.0/44.0 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\rahla\anaconda3\lib\site-packages (from tbats) (1.9.1)
# Requirement already satisfied: numpy in c:\users\rahla\anaconda3\lib\site-packages (from tbats) (1.23.0)
# Requirement already satisfied: scikit-learn in c:\users\rahla\anaconda3\lib\site-packages (from tbats) (1.0.2)
# Requirement already satisfied: pmdarima in c:\users\rahla\anaconda3\lib\site-packages (from tbats) (2.0.4)
# Requirement already satisfied: urllib3 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (1.26.11)
# Requirement already satisfied: pandas>=0.19 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (2.0.3)
# Requirement already satisfied: packaging>=17.1 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (21.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (63.4.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (0.13.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (0.29.32)
# Requirement already satisfied: joblib>=0.11 in c:\users\rahla\anaconda3\lib\site-packages (from pmdarima->tbats) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rahla\anaconda3\lib\site-packages (from scikit-learn->tbats) (2.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\rahla\anaconda3\lib\site-packages (from packaging>=17.1->pmdarima->tbats) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rahla\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima->tbats) (2022.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rahla\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima->tbats) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rahla\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima->tbats) (2.8.2)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\rahla\anaconda3\lib\site-packages (from statsmodels>=0.13.2->pmdarima->tbats) (0.5.2)
# Requirement already satisfied: six in c:\users\rahla\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima->tbats) (1.16.0)
# Installing collected packages: tbats
# Successfully installed tbats-1.1.3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tbats import TBATS

# Fit TBATS model
estimator = TBATS(seasonal_periods=[367.95, 359.77])  # Set detected seasonalities
tbats_model = estimator.fit(y_train)

# Forecast for the next 60 days
horizon = 60
forecast_tbats = tbats_model.forecast(steps=horizon)

# Plot TBATS forecast
plt.figure(figsize=(10, 5))
plt.plot(range(len(y_train)), y_train, label="Train Data", color='blue')
plt.plot(range(len(y_train), len(y_train) + len(y_test)), y_test, label="Actual Test Data", color='green')
plt.plot(range(len(y_train), len(y_train) + horizon), forecast_tbats, label="TBATS Forecast", color='red')
plt.legend()
plt.title("TBATS Forecast")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Calculate error metrics for each forecast

# ARIMA forecast (Fourier)
mae_fc_0 = mean_absolute_error(y_test[:60], fc0)
rmse_fc_0 = np.sqrt(mean_squared_error(y_test[:60], fc0))
mape_fc_0 = np.mean(np.abs((y_test[:60] - fc0) / y_test[:60])) * 100

# ARIMA + Fourier forecast
mae_fc = mean_absolute_error(y_test[:60], forecast_values)
rmse_fc = np.sqrt(mean_squared_error(y_test[:60], forecast_values))
mape_fc = np.mean(np.abs((y_test[:60] - forecast_values) / y_test[:60])) * 100

# TBATS forecast
mae_fc_tbats = mean_absolute_error(y_test[:60], forecast_tbats)
rmse_fc_tbats = np.sqrt(mean_squared_error(y_test[:60], forecast_tbats))
mape_fc_tbats = np.mean(np.abs((y_test[:60] - forecast_tbats) / y_test[:60])) * 100

# Print the results
print("ARIMA Forecast (Fourier):")
print(f"MAE: {mae_fc_0}, RMSE: {rmse_fc_0}, MAPE: {mape_fc_0}")

print("\nARIMA + Fourier Forecast:")
print(f"MAE: {mae_fc}, RMSE: {rmse_fc}, MAPE: {mape_fc}")

print("\nTBATS Forecast:")
print(f"MAE: {mae_fc_tbats}, RMSE: {rmse_fc_tbats}, MAPE: {mape_fc_tbats}")
# Out:
# ARIMA Forecast (Fourier):
# MAE: 10.845961620026893, RMSE: 13.622420740458473, MAPE: nan
#
# ARIMA + Fourier Forecast:
# MAE: 10.725400866492029, RMSE: 13.509779663582107, MAPE: nan
#
# TBATS Forecast:
# MAE: 10.487954417499962, RMSE: 13.349693131980093, MAPE: inf
# C:\Users\rahla\AppData\Local\Temp\ipykernel_16712\3660736801.py:9: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   mape_fc_0 = np.mean(np.abs((y_test[:60] - fc0) / y_test[:60])) * 100
# C:\Users\rahla\AppData\Local\Temp\ipykernel_16712\3660736801.py:14: RuntimeWarning: '<' not supported between instances of 'int' and 'Timestamp', sort order is undefined for incomparable objects.
#   mape_fc = np.mean(np.abs((y_test[:60] - forecast_values) / y_test[:60])) * 100

# %%
import numpy as np

def smape(actual, predicted):
    """
    Compute the Symmetric Mean Absolute Percentage Error (SMAPE)
    
    Parameters:
    - actual: array-like of actual values
    - predicted: array-like of predicted values
    
    Returns:
    - smape value (float)
    """
    actual = np.array(actual)
    predicted = np.array(predicted)
    # Compute SMAPE with a small constant to avoid division by zero
    sm = np.abs(actual - predicted) / (np.abs(actual) + np.abs(predicted) + 1e-12)
    return 200 * np.nanmean(sm)

# Example usage:
smape_fc0 = smape(y_test[:60], fc0)
smape_fc  = smape(y_test[:60], forecast_values)
smape_tbats = smape(y_test[:60], forecast_tbats)

print("SMAPE for ARIMA Forecast (Fourier):", smape_fc0)
print("SMAPE for ARIMA + Fourier Forecast:", smape_fc)
print("SMAPE for TBATS Forecast:", smape_tbats)
# Out:
# SMAPE for ARIMA Forecast (Fourier): 91.67660972417279
# SMAPE for ARIMA + Fourier Forecast: 91.3587088639821
# SMAPE for TBATS Forecast: 90.85794780176849

# %%
import matplotlib.pyplot as plt

# Create a 4-row subplot
fig, axes = plt.subplots(nrows=4, ncols=1, figsize=(10, 12))

# Plot original time series with ARIMA forecast
axes[0].plot(range(len(y_train)), y_train, color='blue', label="Training Data")
axes[0].plot(range(len(y_train), len(y_train) + 60), fc0, color='red', label="ARIMA Forecast (Fourier)")
axes[0].set_title("Original Time Series with ARIMA Forecast (Fourier)")
axes[0].legend()

# Plot ARIMA + Fourier forecast with training data
axes[1].plot(range(len(y_train)), y_train, color='blue', label="Training Data")
axes[1].plot(range(len(y_train), len(y_train) + 60), forecast_values, color='green', label="ARIMA + Fourier Forecast")
axes[1].set_title("Original Time Series with ARIMA + Fourier Forecast")
axes[1].legend()

# Plot TBATS forecast with training data
axes[2].plot(range(len(y_train)), y_train, color='blue', label="Training Data")
axes[2].plot(range(len(y_train), len(y_train) + 60), forecast_tbats, color='orange', label="TBATS Forecast")
axes[2].set_title("Original Time Series with TBATS Forecast")
axes[2].legend()

# Plot only the original time series (for comparison) with actual test data
axes[3].plot(range(len(y_train)), y_train, color='blue', label="Training Data")
axes[3].plot(range(len(y_train), len(y_train) + 60), y_test[:60], color='purple', label="Actual Test Data")
axes[3].set_title("Original Time Series and Actual Test Data")
axes[3].legend()

plt.tight_layout()
plt.show()
